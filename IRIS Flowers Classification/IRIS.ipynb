# %% [markdown]
# # Introduction to Iris_Dataset
#
#
# 1. Title: Iris Plants Database
# 	Updated Sept 21 by C.Blake - Added discrepency information
#
# 2. Sources:
#      (a) Creator: R.A. Fisher
#      (b) Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#      (c) Date: July, 1988
#
# 3. Past Usage:
#    - Publications: too many to mention!!!  Here are a few.
#    1. Fisher,R.A. "The use of multiple measurements in taxonomic problems"
#       Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions
#       to Mathematical Statistics" (John Wiley, NY, 1950).
#    2. Duda,R.O., & Hart,P.E. (1973) Pattern Classification and Scene Analysis.
#       (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    3. Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#       Structure and Classification Rule for Recognition in Partially Exposed
#       Environments".  IEEE Transactions on Pattern Analysis and Machine
#       Intelligence, Vol. PAMI-2, No. 1, 67-71.
#       -- Results:
#          -- very low misclassification rates (0% for the setosa class)
#    4. Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE
#       Transactions on Information Theory, May 1972, 431-433.
#       -- Results:
#          -- very low misclassification rates again
#    5. See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al's AUTOCLASS II
#       conceptual clustering system finds 3 classes in the data.
#
# 4. Relevant Information:
#    --- This is perhaps the best known database to be found in the pattern
#        recognition literature.  Fisher's paper is a classic in the field
#        and is referenced frequently to this day.  (See Duda & Hart, for
#        example.)  The data set contains 3 classes of 50 instances each,
#        where each class refers to a type of iris plant.  One class is
#        linearly separable from the other 2; the latter are NOT linearly
#        separable from each other.
#    --- Predicted attribute: class of iris plant.
#    --- This is an exceedingly simple domain.
#    --- This data differs from the data presented in Fishers article
# 	(identified by Steve Chadwick,  spchadwick@espeedaz.net )
# 	The 35th sample should be: 4.9,3.1,1.5,0.2,"Iris-setosa"
# 	where the error is in the fourth feature.
# 	The 38th sample: 4.9,3.6,1.4,0.1,"Iris-setosa"
# 	where the errors are in the second and third features.
#
# 5. Number of Instances: 150 (50 in each of three classes)
#
# 6. Number of Attributes: 4 numeric, predictive attributes and the class
#
# 7. Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica
#
# 8. Missing Attribute Values: None
#
# Summary Statistics:
# 	         Min  Max   Mean    SD   Class Correlation
#    sepal length: 4.3  7.9   5.84  0.83    0.7826
#     sepal width: 2.0  4.4   3.05  0.43   -0.4194
#    petal length: 1.0  6.9   3.76  1.76    0.9490  (high!)
#     petal width: 0.1  2.5   1.20  0.76    0.9565  (high!)
#
# 9. Class Distribution: 33.3% for each of 3 classes.

# %%
# importing the required libraries

import pandas as pd

# %% [markdown]
# ### Loading the dataset

# %%
# Defining the columns 
columns = ["sepal length","sepal width","petal length","petal width","class"]

# loding the dataset
df = pd.read_csv("iris.csv",names=columns)
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Visualization of dataset

# %%
# importing reduited packages for visualization

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.pairplot(df,hue = "class")

# %% [markdown]
# ### Seperating Input and Output Columns

# %%
# Seperate feature and target

data = df.values

X = data[:,0:4]
y = data[:,4]

# %% [markdown]
# ### Splitting the Data

# %%
# Splitting the data to train and test

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(X_train)
# Out:
# 120

# %%
len(y_train)
# Out:
# 120

# %%
len(X_test)
# Out:
# 30

# %%
len(y_test)
# Out:
# 30

# %% [markdown]
# ### MODEL : 1 ---- SVM (Support Vector mechine)

# %%
from sklearn.svm import SVC
model1 = SVC()
model1.fit(X_train,y_train)
# Out:
# SVC()

# %%
prediction1 = model1.predict(X_test)

# %%
# Calculate the accuracy

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,prediction1)*100)
# Out:
# 100.0

# %%
for i in range(len(prediction1)):
    print(y_test[i],prediction1[i])
# Out:
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,prediction1))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00        11
#  Iris-virginica       1.00      1.00      1.00         9
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### MODEL : 2 ---- Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model2 = LogisticRegression()
model2.fit(X_train,y_train)
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pre_2 = model1.predict(X_test)

# %%
# finding the accuracy

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,pre_2)*100)
# Out:
# 100.0

# %%
for i in range(len(pre_2)):
    print(y_test[i],pre_2[i])
# Out:
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-virginica Iris-virginica
# Iris-versicolor Iris-versicolor
# Iris-setosa Iris-setosa
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor
# Iris-versicolor Iris-versicolor

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pre_2))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00        11
#  Iris-virginica       1.00      1.00      1.00         9
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### MODEL : 3 ----- Decition Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model3 = DecisionTreeClassifier()
model3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_3 = model3.predict(X_test)

# %%
# finding the accuracy

from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred_3)*100
# Out:
# 96.66666666666667

# %%
for i in range(len(pred_3)):
    print('Orginal data is :',y_test[i],'\t The Predicted value of Decision Tree is  : \t',pred_3[i])
# Out:
# Orginal data is : Iris-setosa 	 The Predicted value of Decision Tree is  : 	 Iris-setosa
# Orginal data is : Iris-virginica 	 The Predicted value of Decision Tree is  : 	 Iris-virginica
# Orginal data is : Iris-virginica 	 The Predicted value of Decision Tree is  : 	 Iris-virginica
# Orginal data is : Iris-virginica 	 The Predicted value of Decision Tree is  : 	 Iris-virginica
# Orginal data is : Iris-setosa 	 The Predicted value of Decision Tree is  : 	 Iris-setosa
# Orginal data is : Iris-versicolor 	 The Predicted value of Decision Tree is  : 	 Iris-versicolor
# Orginal data is : Iris-versicolor 	 The Predicted value of Decision Tree is  : 	 Iris-versicolor
# Orginal data is : Iris-versicolor 	 The Predicted value of Decision Tree is  : 	 Iris-versicolor
# Orginal data is : Iris-virginica 	 The Predicted value of Decision Tree is  : 	 Iris-virginica
# Orginal data is : Iris-virginica 	 The Predicted value of Decision Tree is  : 	 Iris-virginica
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_3))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.92      1.00      0.96        11
#  Iris-virginica       1.00      0.89      0.94         9
#
#        accuracy                           0.97        30
#       macro avg       0.97      0.96      0.97        30
#    weighted avg       0.97      0.97      0.97        30

# %%
import numpy as np
new = np.array([[3,2,1,0.2]])
prediction = model1.predict(new)
print(prediction)
# Out:
# ['Iris-setosa']

# %%
new = np.array([[3,2,1,0.2]])
prediction = model2.predict(new)
print(prediction)
# Out:
# ['Iris-setosa']

# %%
new = np.array([[3,2,1,0.2]])
prediction = model3.predict(new)
print(prediction)
# Out:
# ['Iris-setosa']

# %%
new = np.array([[10,3,6,2]])
prediction = model1.predict(new)
print(prediction)
# Out:
# ['Iris-virginica']

# %%
new = np.array([[10,3,6,2]])
prediction = model2.predict(new)
print(prediction)
# Out:
# ['Iris-virginica']

# %%
new = np.array([[10,3,6,2]])
prediction = model3.predict(new)
print(prediction)
# Out:
# ['Iris-virginica']

# %%
new = np.array([[4.9,2.2,3.8,1.1]])
prediction = model1.predict(new)
print(prediction)
# Out:
# ['Iris-versicolor']

# %%
new = np.array([[4.9,2.2,3.8,1.1]])
prediction = model2.predict(new)
print(prediction)
# Out:
# ['Iris-versicolor']

# %%
new = np.array([[4.9,2.2,3.8,1.1]])
prediction = model3.predict(new)
print(prediction)
# Out:
# ['Iris-versicolor']

# %%
new = np.array([[5.3,2.5,4.6,1.9]])
prediction = model1.predict(new)
print(prediction)
# Out:
# ['Iris-versicolor']

# %%
new = np.array([[5.3,2.5,4.6,1.9]])
prediction = model2.predict(new)
print(prediction)
# Out:
# ['Iris-virginica']

# %%
new = np.array([[5.3,2.5,4.6,1.9]])
prediction = model3.predict(new)
print(prediction)
# Out:
# ['Iris-virginica']
